# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
Cycle = pd.read_excel (r'C:\Users\Isaac\Downloads\cycles.xls')

# %%
Cycle.head()
# Out:
#      Year       Date       Player   Game  Inter-arrival Time  Games in Season  \
# 0  1901.0 2004-07-10  Harry Davis  503.0               503.0              NaN
# 1     NaN 2004-07-23  Fred Clarke  593.0                90.0              NaN
# 2     NaN 2004-07-30   Nap Lajoie  642.0                49.0           1110.0
# 3  1902.0        NaT         None    NaN                 NaN           1117.0
# 4  1903.0 2004-05-07  Fred Clarke  115.0              1700.0              NaN
#
#    Unnamed: 6 Unnamed: 7
# 0         NaN        NaN
# 1         NaN        NaN
# 2         NaN        NaN
# 3         NaN        NaN
# 4         NaN        NaN

# %%
len(Cycle)
# Out:
# 245

# %% [markdown]
# The total number of observations is 245. However this is without doing even the lightest amount of cleaning.

# %%
Cycle = Cycle.filter(['Year', 'Date','Player','Game'])

# %%
Cycle = Cycle.dropna()

# %%
Cycle.head()
# Out:
#       Year       Date        Player    Game
# 0   1901.0 2004-07-10   Harry Davis   503.0
# 4   1903.0 2004-05-07   Fred Clarke   115.0
# 8   1904.0 2004-06-20   Duff Cooley   405.0
# 12  1907.0 2004-04-26  Johnny Bates    79.0
# 13  1908.0 2004-10-02   Otis Clymer  1200.0

# %%
len(Cycle)
# Out:
# 86

# %% [markdown]
# After doing some intense cleaning, there are 4 variables and 86 observations.

# %%
Cycle.dtypes
# Out:
# Year             float64
# Date      datetime64[ns]
# Player            object
# Game             float64
# dtype: object

# %% [markdown]
# Both the year and game variables are float values, with date being time specific, and player being a string.

# %%
Cycle.filter(["Game"]) \
.agg('mean')


476/162
# Out:
# Game    476.267442
# dtype: float64
# 2.9382716049382718

# %% [raw]
# The average game players hit for the cycle in their career is game 476. This means a player gets through basically 3 seasons, on average, when they hit for the cycle.

# %%
Cycle = Cycle.astype(str)
plot = Cycle['Year'].value_counts().plot(kind = "pie").axis('equal')

# %% [markdown]
# Treating the Year column as a string, thus making it a categorical variable, we are able to visualize the proportion of cycles hit in each year for all cycles. Based on the pie chart, there appears to be an approximately equal proportionality between all of the years.
